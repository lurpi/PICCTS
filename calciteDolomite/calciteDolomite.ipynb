# %%
import os

os.environ["PATH"] = (
    os.path.abspath("${HOME}/pflotran-binder") + os.pathsep +
    os.path.abspath("${HOME}/pflotran-binder/pflotran") + os.pathsep +
    os.path.abspath("${HOME}/pflotran-binder/petsc") + os.pathsep +
    os.path.abspath("/home/jovyan/pflotran-binder/petsc/binder-gnu/bin/") + os.pathsep +

    os.environ["PATH"]
)
os.environ["PFLOTRAN_DIR"] = (
    os.path.abspath("/home/jovyan/pflotran-binder/pflotran")
)
os.environ["PETSC_DIR"] = (
    os.path.abspath("${HOME}/pflotran-binder/petsc")
)

# %%
# %run calciteDolomite.py
